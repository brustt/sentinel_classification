# %%
import otbApplication as otb
import pyotb
import os
# Out:
# 2024-01-14 00:00:17 (INFO) [pyotb] Successfully loaded 117 OTB applications

# %%
project_dir = "/home/rustt/Documents/Projects/S1_S2_classification"
data_dir = os.path.join(project_dir, "sentinel_classification/data/processed")
model_dir = os.path.join(project_dir, "sentinel_classification/models")
out_dir = os.path.join(project_dir, "sentinel_classification/data/final")

# %%
s2_stack_path = os.path.join(data_dir, "s2", "clip_s2_pan_sharp.tif")
labels_path = os.path.join(data_dir, "ROI_Classif_corrected_clf.shp")

# %% [markdown]
# ### OTB classifier general params
#
# #### Maximum training sample size per class `-sample.mt` int Default value: 1000
#
# Maximum size per class (in pixels) of the training sample list (default = 1000) (no limit = -1). If equal to -1, then the maximal size of the available training sample list per class will be equal to the surface area of the smallest class multiplied by the training sample ratio.
#
# ####  Maximum validation sample size per class `-sample.mv` int Default value: 1000
#
# Maximum size per class (in pixels) of the validation sample list (default = 1000) (no limit = -1). If equal to -1, then the maximal size of the available validation sample list per class will be equal to the surface area of the smallest class multiplied by the validation sample ratio.
#
# ####  Bound sample number by minimum `-sample.bm` int Default value: 1
#
# Bound the number of samples for each class by the number of available samples by the smaller class. Proportions between training and validation are respected. Default is true (=1).
#
# ####  Training and validation sample ratio `-sample.vtr` float Default value: 0.5
#
# Ratio between training and validation samples (0.0 = all training, 1.0 = all validation) (default = 0.5).
#
# ####  Field containing the class integer label for supervision `-sample.vfn` string
#
# Field containing the class id for supervision. The values in this field shall be cast into integers.
#
# ### Sklearn vs otb
# - max features == rf.var default : 0 <==> sqrt(p)

# %% [markdown]
# ### PyOTB

# %%
out_model = os.path.join(model_dir, "rf_test.txt")
out_confmat = os.path.join(model_dir, "rf_test.csv")

# %%
params_io = {
    # input
    "io.il":s2_stack_path, 
    "io.vd":labels_path,
    # output
    "io.out": out_model,
    "io.confmatout":out_confmat, 
    
}

params_sample = {
    "sample.vfn": "classid", #class label column
    "sample.mt":1000, # max sample train set
    "sample.mv":1000, # max sample test set
    "sample.bm":1, # keep balanced dataset
    "sample.vtr":0.3, # size test
}

params_clf = {
    "classifier":"rf",
    "classifier.rf.max":5,
    "classifier.rf.min": 10,
    "classifier.rf.var": 0, # number of features use for building tree
    "classifier.rf.nbtrees":100,
    
}
params_other = {
    "ram":6144
}

params_training = dict(
    **params_io, 
    **params_clf,
    **params_sample, 
    **params_other,

)

# %%
params_training
# Out:
# {'io.il': '/home/rustt/Documents/Projects/S1_S2_classification/sentinel_classification/data/processed/s2/clip_s2_pan_sharp.tif',
#  'io.vd': '/home/rustt/Documents/Projects/S1_S2_classification/sentinel_classification/data/processed/ROI_Classif_corrected_clf.shp',
#  'io.out': '/home/rustt/Documents/Projects/S1_S2_classification/sentinel_classification/models/rf_test.txt',
#  'io.confmatout': '/home/rustt/Documents/Projects/S1_S2_classification/sentinel_classification/models/rf_test.csv',
#  'classifier': 'rf',
#  'classifier.rf.max': 5,
#  'classifier.rf.min': 10,
#  'classifier.rf.var': 0,
#  'classifier.rf.nbtrees': 100,
#  'sample.vfn': 'classid',
#  'sample.mt': 1000,
#  'sample.mv': 1000,
#  'sample.bm': 1,
#  'sample.vtr': 0.3,
#  'ram': 512}

# %% [markdown]
# Erreur avec parametre sample.vfn => modifier pyotb/core.py l1026 :
#
# workaround trouvé :
# * setParameterString(key, obj) for key == "sample.vfn"
# * todo : create issue github
#
# setParameterValue in pyotb code by default

# %%
pyotb.TrainImagesClassifier(params_training)
# Out:
# 2024-01-14 00:00:59 (INFO) [pyotb] TrainImagesClassifier: argument for parameter "io.il" was converted to list
# 2024-01-14 00:00:59 (INFO) [pyotb] params io.il set !
# 2024-01-14 00:00:59 (INFO) [pyotb] TrainImagesClassifier: argument for parameter "io.vd" was converted to list
# 2024-01-14 00:00:59 (INFO) [pyotb] params io.vd set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params io.out set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params io.confmatout set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params classifier set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params classifier.rf.max set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params classifier.rf.min set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params classifier.rf.var set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params classifier.rf.nbtrees set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params sample.vfn set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params sample.mt set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params sample.mv set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params sample.bm set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params sample.vtr set !
# 2024-01-14 00:00:59 (INFO) [pyotb] params ram set !
# 2024-01-14 00:00:59 (INFO): Loading metadata from official product
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Polygon analysis...
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Elevation management: setting default height above ellipsoid to 0 meters
# 2024-01-14 00:00:59 (INFO): Default RAM limit for OTB is 256 MB
# 2024-01-14 00:00:59 (INFO): GDAL maximum cache size is 1567 MB
# 2024-01-14 00:00:59 (INFO): OTB will use at most 16 threads
# 2024-01-14 00:00:59 (INFO): Estimated memory for full processing: 1710.85MB (avail.: 512 MB), optimal image partitioning: 4 blocks
# 2024-01-14 00:00:59 (INFO): Estimation will be performed in 6 blocks of 2176x2176 pixels
# Analyze polygons...: 100% [**************************************************] (0s)
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Sampling rates...
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Sampling strategy : fit the number of samples based on the smallest class
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Sampling rates for image 1 :  className  requiredSamples  totalSamples  rate
# 1	11393	52132	0.218541
# 11	11393	13263	0.859006
# 12	11393	17397	0.654883
# 13	11393	20424	0.557824
# 2	11393	48323	0.235768
# 3	11393	14679	0.776143
# 4	11393	20701	0.55036
# 5	11393	11393	1
# 6	11393	225949	0.0504229
# 7	11393	18055	0.631016
#
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Sample selection...
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Elevation management: setting default height above ellipsoid to 0 meters
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Sampling strategy : set number of samples for each class
# 2024-01-14 00:00:59 (INFO) TrainImagesClassifier: Sampling rates :  className  requiredSamples  totalSamples  rate
# 1	11393	52132	0.218541
# 11	11393	13263	0.859006
# 12	11393	17397	0.654883
# 13	11393	20424	0.557824
# 2	11393	48323	0.235768
# 3	11393	14679	0.776143
# 4	11393	20701	0.55036
# 5	11393	11393	1
# 6	11393	225949	0.0504229
# 7	11393	18055	0.631016
#
# 2024-01-14 00:00:59 (INFO): Estimated memory for full processing: 1710.85MB (avail.: 512 MB), optimal image partitioning: 4 blocks
# 2024-01-14 00:00:59 (INFO): Estimation will be performed in 6 blocks of 2368x2368 pixels
# Selecting positions with periodic sampler...: 100% [**************************************************] (0s)
# 2024-01-14 00:01:00 (INFO) TrainImagesClassifier: Sample extraction...
# 2024-01-14 00:01:03 (INFO): Estimated memory for full processing: 2566.47MB (avail.: 512 MB), optimal image partitioning: 6 blocks
# 2024-01-14 00:01:03 (INFO): Estimation will be performed in 9 blocks of 1920x1792 pixels
# Extracting sample values...: 100% [**************************************************] (3s)
# 2024-01-14 00:01:07 (INFO): Estimated memory for full processing: 1710.85MB (avail.: 512 MB), optimal image partitioning: 4 blocks
# 2024-01-14 00:01:07 (INFO): Estimation will be performed in 6 blocks of 2368x2368 pixels
# Split samples between training and validation...: 100% [**************************************************] (2s)
# 2024-01-14 00:01:09 (INFO) TrainImagesClassifier: Model training...
# 2024-01-14 00:01:09 (INFO) TrainImagesClassifier: Reading vector file 1/1
# 2024-01-14 00:01:09 (INFO) TrainImagesClassifier: Reading vector file 1/1
# 2024-01-14 00:01:10 (INFO) TrainImagesClassifier: Computing model file : /home/rustt/Documents/Projects/S1_S2_classification/sentinel_classification/models/rf_test.txt
# Training model...: 100% [**************************************************] (9s)
# Validation...: 100% [**************************************************] (0s)
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Predicted list size : 34170
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: ValidationLabeledListSample size : 34170
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Training performances:
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Confusion matrix (rows = reference labels, columns = produced labels):
#      [1] [2] [3] [4] [5] [6] [7] [11] [12] [13]
# [ 1] 2696   55    4   14  137    0    0   27  484    0
# [ 2]    3 3131    0   36  218    0    0    0   29    0
# [ 3]    0    0 3236  157   17    0    7    0    0    0
# [ 4]    0   60  689 2336   27    0  301    0    0    4
# [ 5]  112  120   10    6 3141    0    0    7   21    0
# [ 6]    0    0    0    0    0 3417    0    0    0    0
# [ 7]    0    2  170  115    0    0 2918    0    0  212
# [11]   40    2    0    0  115    0    0 3049  211    0
# [12]  739  110    0    2   30    0    0    2 2534    0
# [13]    0    0    8   61    3    0  331    0    0 3014
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [1] vs all: 0.750975
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [1] vs all: 0.788996
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [1] vs all: 0.769516
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [2] vs all: 0.899713
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [2] vs all: 0.916301
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [2] vs all: 0.907931
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [3] vs all: 0.786009
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [3] vs all: 0.94703
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [3] vs all: 0.859039
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [4] vs all: 0.856619
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [4] vs all: 0.683641
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [4] vs all: 0.760417
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [5] vs all: 0.851681
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [5] vs all: 0.919227
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [5] vs all: 0.884166
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [6] vs all: 1
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [6] vs all: 1
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [6] vs all: 1
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [7] vs all: 0.820354
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [7] vs all: 0.853965
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [7] vs all: 0.836822
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [11] vs all: 0.988331
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [11] vs all: 0.892303
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [11] vs all: 0.937865
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [12] vs all: 0.772797
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [12] vs all: 0.741586
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [12] vs all: 0.75687
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Precision of class [13] vs all: 0.933127
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Recall of class    [13] vs all: 0.88206
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: F-score of class   [13] vs all: 0.906875
#
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Global performance, Kappa index: 0.847234
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[0] = 1
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[1] = 2
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[2] = 3
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[3] = 4
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[4] = 5
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[5] = 6
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[6] = 7
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[7] = 11
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[8] = 12
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: mapOfIndicesValid[9] = 13
# 2024-01-14 00:01:19 (INFO) TrainImagesClassifier: Final clean-up ...
# <pyotb.TrainImagesClassifier object, id 140445844211264>

# %% [markdown]
# ### Remarques
# * comment récupérer le train/test ? (qui a été échantilloné)
#     * controler sur-apprentissage
#     * Utiliser les modules séparemments de la classification : https://www.orfeo-toolbox.org/CookBook/recipes/pbclassif.html
# * charger le modèle ? => via cv2 CVRTree

# %% [markdown]
# ### OTB

# %%
app = otbApplication.Registry.CreateApplication("TrainImagesClassifier")

app.SetParameterStringList("io.il", [s2_stack_path])
app.SetParameterStringList("io.vd", [labels_path])
#app.SetParameterString("io.imstat", "EstimateImageStatisticsQB1.xml")
app.SetParameterInt("sample.mv", 1000)
app.SetParameterInt("sample.mt", 1000)
app.SetParameterFloat("sample.vtr", 0.3)
app.SetParameterString("sample.vfn", "classid")
app.SetParameterString("classifier","rf")
app.SetParameterInt("classifier.rf.nbtrees", 100)
app.SetParameterString("io.out", out_model)
app.SetParameterString("io.confmatout", out_confmat)

app.ExecuteAndWriteOutput()

# %% [markdown]
# ## Annexes

# %%
pyotb.get_available_applications()
# Out:
# 2024-01-13 19:49:41 (INFO) [pyotb] Successfully loaded 117 OTB applications
# ('Aggregate',
#  'BandMath',
#  'BandMathX',
#  'BinaryMorphologicalOperation',
#  'BlockMatching',
#  'BundleToPerfectSensor',
#  'ClassificationMapRegularization',
#  'ColorMapping',
#  'CompareImages',
#  'ComputeConfusionMatrix',
#  'ComputeImagesStatistics',
#  'ComputeModulusAndPhase',
#  'ComputeOGRLayersFeaturesStatistics',
#  'ConcatenateImages',
#  'ConcatenateVectorData',
#  'ConnectedComponentSegmentation',
#  'ContrastEnhancement',
#  'ConvertCartoToGeoPoint',
#  'ConvertSensorToGeoPoint',
#  'Despeckle',
#  'DimensionalityReduction',
#  'DisparityMapToElevationMap',
#  'DomainTransform',
#  'DynamicConvert',
#  'EdgeExtraction',
#  'EndmemberNumberEstimation',
#  'ExtractROI',
#  'FastNLMeans',
#  'FineRegistration',
#  'FusionOfClassifications',
#  'GeneratePlyFile',
#  'GenericRegionMerging',
#  'GrayScaleMorphologicalOperation',
#  'GridBasedImageResampling',
#  'HaralickTextureExtraction',
#  'HomologousPointsExtraction',
#  'HooverCompareSegmentation',
#  'HyperspectralUnmixing',
#  'ImageClassifier',
#  'ImageDimensionalityReduction',
#  'ImageEnvelope',
#  'ImageRegression',
#  'ImageTimeSeriesGapFilling',
#  'KMeansClassification',
#  'LSMSSegmentation',
#  'LSMSSmallRegionsMerging',
#  'LSMSVectorization',
#  'LargeScaleMeanShift',
#  'LineSegmentDetection',
#  'LocalRxDetection',
#  'LocalStatisticExtraction',
#  'ManageNoData',
#  'MeanShiftSmoothing',
#  'MorphologicalClassification',
#  'MorphologicalMultiScaleDecomposition',
#  'MorphologicalProfilesAnalysis',
#  'Mosaic',
#  'MultiImageSamplingRate',
#  'MultiResolutionPyramid',
#  'MultitempFilteringFilter',
#  'MultitempFilteringOutcore',
#  'MultivariateAlterationDetector',
#  'OGRLayerClassifier',
#  'OSMDownloader',
#  'ObjectsRadiometricStatistics',
#  'ObtainUTMZoneFromGeoPoint',
#  'OpticalCalibration',
#  'OrthoRectification',
#  'Pansharpening',
#  'PantexTextureExtraction',
#  'PixelValue',
#  'PolygonClassStatistics',
#  'Quicklook',
#  'RadiometricIndices',
#  'Rasterization',
#  'ReadImageInfo',
#  'Rescale',
#  'ResetMargin',
#  'RigidTransformResample',
#  'SARBurstExtraction',
#  'SARCalibration',
#  'SARConcatenateBursts',
#  'SARDeburst',
#  'SARDecompositions',
#  'SARPolarMatrixConvert',
#  'SARPolarSynth',
#  'SFSTextureExtraction',
#  'SOMClassification',
#  'SampleAugmentation',
#  'SampleExtraction',
#  'SampleSelection',
#  'Segmentation',
#  'SmallRegionsMerging',
#  'Smoothing',
#  'SpectralAngleClassification',
#  'SplitImage',
#  'StereoFramework',
#  'StereoRectificationGridGenerator',
#  'Superimpose',
#  'Synthetize',
#  'TestApplication',
#  'TileFusion',
#  'TrainDimensionalityReduction',
#  'TrainImagesClassifier',
#  'TrainImagesRegression',
#  'TrainRegression',
#  'TrainVectorClassifier',
#  'TrainVectorRegression',
#  'VectorClassifier',
#  'VectorDataExtractROI',
#  'VectorDataReprojection',
#  'VectorDataSetField',
#  'VectorDataTransform',
#  'VectorDimensionalityReduction',
#  'VectorRegression',
#  'VertexComponentAnalysis',
#  'ZonalStatistics')
